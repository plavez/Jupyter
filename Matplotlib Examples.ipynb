# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\vladigolic\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
values=[0,1,2,3,4,5,6,7]
squares=[value ** 2 for value in values]
plt.plot(values,squares)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(values,squares)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
values=list(range(100))
pows=[pow(value,3) for value in values]
plt.scatter(values,pows)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(values,pows, c=pows,cmap=plt.cm.Blues, edgecolors='none',s=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
values=list(range(50))
squares = [pow(value,2) for value in values]
cubes = [pow(value,3) for value in values]

fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)
ax1.scatter(values,squares)
ax1.set_title('Square numbers')
ax2.plot(values,cubes)
ax2.set_title('Cube numbers')
plt.show()

# %%
values=list(range(10))
squares = [pow(value,2) for value in values]
cubes = [pow(value,3) for value in values]

fig,(ax1,ax2) = plt.subplots(1,2,sharey=True)
ax1.scatter(values,squares)
ax1.set_title('Square numbers')
ax2.plot(values,cubes)
ax2.set_title('Cube numbers')
plt.show()

# %%
data={
    'Year':[2001,2002,2003,2004,2005,2006],
    'Sales':[100,150,130,180,210,230]
    
}
df=pd.DataFrame(data)
df.plot(x='Year',y='Sales',kind='line',color=('red','blue'))
plt.title('Yearly Sales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data={
    'Year':[2001,2002,2003,2004,2005,2006],
    'Sales':[100,150,130,180,210,230]
    
}
df=pd.DataFrame(data)
df.plot(x='Year',y='Sales',kind='bar',color=('red','blue'))
plt.title('Yearly Sales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data={
    'Year':[2001,2002,2003,2004,2005,2006],
    'Sales':[100,150,130,180,210,230]
    
}
df=pd.DataFrame(data)
df.plot(x='Year',y='Sales',kind='area',color=('blue'))
plt.title('Yearly Sales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data={
    'Year':[2001,2002,2003,2004,2005,2006],
    'Sales':[100,150,130,180,210,230]
    
}
df=pd.DataFrame(data)
df.plot(y='Sales',kind='pie',labels=df['Year'],autopct='%1.2f%%')
plt.title('Yearly Sales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data={
    'Age':[25,28,32,41,42,42,50,59,60]
}

df=pd.DataFrame(data)
df.plot(y = 'Age',kind='hist')
plt.title('Age disrubution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data={
    'Category':['FIRST','FIRST','SECOND','SECOND','THIRD','THIRD'],
    'Value':[10,20,25,45,45,50]
    
}
df= pd.DataFrame(data)
df
# Out:
#   Category  Value
# 0    FIRST     10
# 1    FIRST     20
# 2   SECOND     25
# 3   SECOND     45
# 4    THIRD     45
# 5    THIRD     50

# %%
df.boxplot(by='Category',column='Value')
plt.title('Values distribution by category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data={
    'Month':['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Okt','Nov','Dec'],
    'Wek 1 Temp':[6,4,10,17,20,25,27,26,25,20,15,7],
    'Week 2 Temp':[5,4,9,18,22,26,26,22,20,17,16,3],
    'Week 3 Temp':[4,6,14,15,20,24,28,24,23,13,11,1],
    'Week 4 Temp':[2,2,11,20,23,22,25,25,21,16,12,2]
}
df=pd.DataFrame(data)
df
# Out:
#    Month  Wek 1 Temp  Week 2 Temp  Week 3 Temp  Week 4 Temp
# 0    Jan           6            5            4            2
# 1    Feb           4            4            6            2
# 2    Mar          10            9           14           11
# 3    Apr          17           18           15           20
# 4    May          20           22           20           23
# 5    Jun          25           26           24           22
# 6    Jul          27           26           28           25
# 7    Aug          26           22           24           25
# 8    Sep          25           20           23           21
# 9    Okt          20           17           13           16
# 10   Nov          15           16           11           12
# 11   Dec           7            3            1            2

# %%
df.set_index('Month',inplace=True)
df
# Out:
#        Wek 1 Temp  Week 2 Temp  Week 3 Temp  Week 4 Temp
# Month
# Jan             6            5            4            2
# Feb             4            4            6            2
# Mar            10            9           14           11
# Apr            17           18           15           20
# May            20           22           20           23
# Jun            25           26           24           22
# Jul            27           26           28           25
# Aug            26           22           24           25
# Sep            25           20           23           21
# Okt            20           17           13           16
# Nov            15           16           11           12
# Dec             7            3            1            2

# %%
sns.heatmap(df,cmap='coolwarm',annot=True)
plt.title('Weekly temperature data')
plt.show()
